# %%
import importlib
import model
importlib.reload(model)
import os
from model import EyeStateModel
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
model = EyeStateModel()

# %%
model.train(train_dir = "D://python_code//Individual_model//BTLPYTHON//BE//data/train",
            val_dir = "D://python_code//Individual_model//BTLPYTHON//BE//data/test",epochs = 20)
# Out:
# Found 81675 images belonging to 2 classes.
# Found 3223 images belonging to 2 classes.
# Epoch 1/20
# 2553/2553 [==============================] - 974s 381ms/step - loss: 0.1929 - accuracy: 0.9250 - val_loss: 0.2606 - val_accuracy: 0.8998
# Epoch 2/20
# 2553/2553 [==============================] - 467s 183ms/step - loss: 0.1057 - accuracy: 0.9630 - val_loss: 0.2245 - val_accuracy: 0.9299
# Epoch 3/20
# 2553/2553 [==============================] - 452s 177ms/step - loss: 0.0858 - accuracy: 0.9705 - val_loss: 0.1941 - val_accuracy: 0.9352
# Epoch 4/20
# 2553/2553 [==============================] - 462s 181ms/step - loss: 0.0760 - accuracy: 0.9733 - val_loss: 0.2165 - val_accuracy: 0.9317
# Epoch 5/20
# 2553/2553 [==============================] - 468s 183ms/step - loss: 0.0683 - accuracy: 0.9756 - val_loss: 0.3167 - val_accuracy: 0.9203
# Epoch 6/20
# ...

# %%
model.save("eye_model.h5")
# Out:
#  Model saved to eye_model.h5
