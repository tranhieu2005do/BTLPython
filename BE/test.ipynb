# %%
import importlib
import preprocessing
import model.model
importlib.reload(preprocessing)
importlib.reload(model.model)
import cv2
import numpy as np
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
from preprocessing import Preprocessing 
from model.model import EyeStateModel
import matplotlib.pyplot as plt

# %%
pre = Preprocessing(img_size=(101, 101))

img_path = r"D:\python_code\Individual_model\BTLPYTHON\BE\1.jpg"

img, res = pre.preprocess_and_visualize(img_path)
print(len(res))
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 1)
plt.title("Detect")
plt.imshow(img)

plt.subplot(1, 3, 2)
plt.title("Left")
plt.imshow(res[0], cmap='gray')

plt.subplot(1, 3, 3)
plt.title("Right")
plt.imshow(res[1], cmap='gray')
plt.show()
# Out:
# 2

# %%
model = EyeStateModel()

model.load("eye_model.h5")
# Out:
# Model loaded from eye_model.h5

# %%
print(res[0].shape)
# Out:
# (101, 101, 1)

# %%
label, prob = model.predict(res[1])
print(label)
print(prob)
# Out:
# 1/1 [==============================] - 0s 46ms/step
# Dự đoán: Closed (0.00)
# Closed
# 3.5934774e-17
